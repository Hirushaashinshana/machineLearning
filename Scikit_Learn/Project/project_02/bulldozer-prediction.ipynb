# %% [markdown]
# # Predicting the Sale Price of Bulldozers using Machine Learning
#
# In this notebook, we're going to go through an example machine learning project with the goal of predicting the sale price of bulldozers.
#
# ## 1. Problem definition
# Predict the auction sale price for a piece of heavy equipment to create a "blue book" for bulldozers.
#
# ## 2. Data
#
# * Train.csv is the training set, which contains data through the end of 2011.
#
# * Valid.csv is the validation set, which contains data from January 1, 2012 - April 30, 2012 You make predictions on this set throughout the majority of the competition. Your score on this set is used to create the public leaderboard.
#
# * Test.csv is the test set, which won't be released until the last week of the competition. It contains data from May 1, 2012 - November 2012. Your score on the test set determines your final rank for the competition.
#
# ## 3. Evaluation
#
# The evaluation metric for this competition is the RMSLE (root mean squared log error) between the actual and predicted auction prices.
#
#
# ## 4. Features

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import sklearn

# %%
# Import training and validation sets
df = pd.read_csv('./data/bluebook-for-bulldozers/TrainAndValid.csv',
                low_memory=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42379 entries, 0 to 42378
# Data columns (total 53 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   SalesID                   42379 non-null  int64
#  1   SalePrice                 42379 non-null  int64
#  2   MachineID                 42379 non-null  int64
#  3   ModelID                   42379 non-null  int64
#  4   datasource                42379 non-null  int64
#  5   auctioneerID              42379 non-null  int64
#  6   YearMade                  42379 non-null  int64
#  7   MachineHoursCurrentMeter  24901 non-null  float64
#  8   UsageBand                 21975 non-null  object
#  9   saledate                  42379 non-null  object
#  10  fiModelDesc               42379 non-null  object
#  11  fiBaseModel               42379 non-null  object
#  12  fiSecondaryDesc           27048 non-null  object
#  13  fiModelSeries             3823 non-null   object
#  14  fiModelDescriptor         6694 non-null   object
#  15  ProductSize               14783 non-null  object
#  16  fiProductClassDesc        42379 non-null  object
#  17  state                     42379 non-null  object
#  18  ProductGroup              42379 non-null  object
#  19  ProductGroupDesc          42379 non-null  object
#  20  Drive_System              13374 non-null  object
#  21  Enclosure                 42361 non-null  object
#  22  Forks                     27366 non-null  object
#  23  Pad_Type                  11878 non-null  object
#  24  Ride_Control              18392 non-null  object
#  25  Stick                     11878 non-null  object
#  26  Transmission              18653 non-null  object
#  27  Turbocharged              11877 non-null  object
#  28  Blade_Extension           1493 non-null   object
#  29  Blade_Width               1493 non-null   object
#  30  Enclosure_Type            1493 non-null   object
#  31  Engine_Horsepower         1493 non-null   object
#  32  Hydraulics                30437 non-null  object
#  33  Pushblock                 1493 non-null   object
#  34  Ripper                    6769 non-null   object
#  35  Scarifier                 1493 non-null   object
#  36  Tip_Control               1493 non-null   object
#  37  Tire_Size                 8001 non-null   object
#  38  Coupler                   23577 non-null  object
#  39  Coupler_System            8983 non-null   object
#  40  Grouser_Tracks            8967 non-null   object
#  41  Hydraulics_Flow           8967 non-null   object
#  42  Track_Type                8023 non-null   object
#  43  Undercarriage_Pad_Width   8046 non-null   object
#  44  Stick_Length              8024 non-null   object
#  45  Thumb                     8027 non-null   object
#  46  Pattern_Changer           8024 non-null   object
#  47  Grouser_Type              8023 non-null   object
#  48  Backhoe_Mounting          5266 non-null   object
#  49  Blade_Type                5311 non-null   object
#  50  Travel_Controls           5310 non-null   object
#  51  Differential_Type         6508 non-null   object
#  52  Steering_Controls         6507 non-null   object
# dtypes: float64(1), int64(7), object(45)
# memory usage: 17.1+ MB

# %%
df.isna().sum()
# Out:
# SalesID                         0
# SalePrice                       0
# MachineID                       0
# ModelID                         0
# datasource                      0
# auctioneerID                    0
# YearMade                        0
# MachineHoursCurrentMeter    17478
# UsageBand                   20404
# saledate                        0
# fiModelDesc                     0
# fiBaseModel                     0
# fiSecondaryDesc             15331
# fiModelSeries               38556
# fiModelDescriptor           35685
# ProductSize                 27596
# fiProductClassDesc              0
# state                           0
# ProductGroup                    0
# ProductGroupDesc                0
# Drive_System                29005
# Enclosure                      18
# Forks                       15013
# Pad_Type                    30501
# Ride_Control                23987
# Stick                       30501
# Transmission                23726
# Turbocharged                30502
# Blade_Extension             40886
# Blade_Width                 40886
# Enclosure_Type              40886
# Engine_Horsepower           40886
# Hydraulics                  11942
# Pushblock                   40886
# Ripper                      35610
# Scarifier                   40886
# Tip_Control                 40886
# Tire_Size                   34378
# Coupler                     18802
# Coupler_System              33396
# Grouser_Tracks              33412
# Hydraulics_Flow             33412
# Track_Type                  34356
# Undercarriage_Pad_Width     34333
# Stick_Length                34355
# Thumb                       34352
# Pattern_Changer             34355
# Grouser_Type                34356
# Backhoe_Mounting            37113
# Blade_Type                  37068
# Travel_Controls             37069
# Differential_Type           35871
# Steering_Controls           35872
# dtype: int64

# %%
fig, ax = plt.subplots()
ax.scatter(df['saledate'][:1000], df['SalePrice'][:1000], c='#e61c55')

# %%
df = pd.read_csv("data/bluebook-for-bulldozers/TrainAndValid.csv",
                low_memory=False,
                parse_dates=["saledate"])

# %%
df.saledate.dtype
# Out:
# dtype('<M8[ns]')

# %%
fig, ax = plt.subplots()
ax.scatter(df["saledate"][:1000], df["SalePrice"][:1000])
